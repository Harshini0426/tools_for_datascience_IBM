# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# Add your code below following the instructions given in the course

# %% [markdown]
# ## Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, we can see the basics of data science tools and ecosystem

# %% [markdown]
# The most common data science languages used are:
#
# 1.Python \
# 2.C++\
# 3.Java

# %% [markdown]
# **Objectives**
#
# * Languages used in Data science are Python, C++, Java
# * The popular libraries used are Matplotlib, numpy, scipy and sklearn
# * The widely used environments are VS Code, R Studio, Google Colab

# %% [markdown]
# Some of the most common data science libraries used are:
#
# 1.matplotlib \
# 2.numpy \
# 3.scipy \
# 4.sklearn

# %% [markdown]
# ## 6

# %% [markdown]
# | Data Science Tools |
# | ------------------- |
# | Jupyter Notebook |
# | RStudio |
# | Visual Studio Code |

# %% [markdown]
# ## 7th

# %% [markdown]
# Below are the few examples of arithematic operations in python
#
# Eg 1: 3+5 = 8 \
# Eg 2: 987-900 = 87 \
# Eg 3: 80^2 = 160 \
# Eg 4: 256/16 = 16

# %% [markdown]
# ### 8th - Multiply numbers

# %%
print((3*4)+5)
# Out:
# 17

# %% [markdown]
# ### 9th - Create a code cell to convert minutes to hours

# %%
print("200 minutes is equal to", 200/60, "hours")
# Out:
# 200 minutes is equal to 3.3333333333333335 hours

# %% [markdown]
# ### 11th

# %% [markdown]
# ## Author
# Harshini
